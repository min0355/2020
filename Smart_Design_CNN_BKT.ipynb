# %% [markdown]
# <a href="https://colab.research.google.com/github/min0355/2020/blob/master/Smart_Design_CNN_BKT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
    print('User uploaded file "{name}" with length {length} bytes'.format(name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-d51e9da8-b636-46b2-894d-e2a9baaf2809" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d51e9da8-b636-46b2-894d-e2a9baaf2809">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data_3000.zip to data_3000 (2).zip
# User uploaded file "data_3000.zip" with length 3309996 bytes

# %%
from google.colab import drive # 드라이브 마운트에 연결하기 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !mkdir data_3000.zip                # 마운트에 폴더 생성 
# !unzip data_3000.zip -d ./data_3000 # unzip
# Out:
# mkdir: cannot create directory ‘data_3000.zip’: File exists
# Archive:  data_3000.zip
# replace ./data_3000/22.5651.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: ./data_3000/22.5651.jpg
#   inflating: ./data_3000/23.119.jpg
#   inflating: ./data_3000/23.149.jpg
#   inflating: ./data_3000/23.2255.jpg
#   inflating: ./data_3000/23.2919.jpg
#   inflating: ./data_3000/23.3077.jpg
#   inflating: ./data_3000/23.3701.jpg
#   inflating: ./data_3000/23.388.jpg
#   inflating: ./data_3000/23.4496.jpg
#   inflating: ./data_3000/23.4706.jpg
#   inflating: ./data_3000/23.4709.jpg
#   inflating: ./data_3000/23.4904.jpg
#   inflating: ./data_3000/23.5079.jpg
#   inflating: ./data_3000/23.5414.jpg
#   inflating: ./data_3000/23.5748.jpg
#   inflating: ./data_3000/23.5762.jpg
#   inflating: ./data_3000/23.587.jpg
#   inflating: ./data_3000/23.5886.jpg
#   inflating: ./data_3000/23.5889.jpg
#   inflating: ./data_3000/23.6748.jpg
#   inflating: ./data_3000/23.6771.jpg
# ...

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
src = './data_3000'

# %%
def img_read_plot(src, file):
    img = cv.imread(src+file, cv.COLOR_BGR2GRAY)
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])
    plt.show()
    
    return img

# %%
def img_read(src, file):
    img = cv.imread(src_file, cv.COLOR_BGR2GRAY)

    return img

# %%
# src 경로에 있는 파일명 저장
files = os.listdir(src)

X, Y = [], []
count = 0

# %%
# 데이터를 255 로 나누고 0 ~ 1 사이로 정규화하여 X 에 입력
for file in files:
    if count < 10:
        print(count)
        X.append(img_read_plot(src, file)/255.)
        Y.append(float(file[:-4]))
        count += 1
    
    else:
        X.append(img_read(src, file)/255.)
        Y.append(float(file[:-4]))

X = np.array(X)
Y = np.array(Y)

print("X_shape: ", np.shape(X[0]), 'Y_shape: ', np.shape(Y[0]))
print("X_list shape: ", np.shape(X), 'Y_list shape: ', np.shape(Y))
# Out:
# 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-aa1c345e930c> in <module>()
#       3     if count < 10:
#       4         print(count)
# ----> 5         X.append(img_read_plot(src, file)/255.)
#       6         Y.append(float(file[:-4]))
#       7         count += 1
#
# <ipython-input-43-1a2faf7ffee3> in img_read_plot(src, file)
#       1 def img_read_plot(src, file):
#       2     img = cv.imread(src+file, cv.COLOR_BGR2GRAY)
# ----> 3     plt.imshow(img)
#       4     plt.xticks([])
#       5     plt.yticks([])
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
# ...
